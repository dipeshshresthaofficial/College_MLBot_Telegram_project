# %%
#installing pytelegrambot API

! pip install pytelegrambotapi

# %%
#importing libraries from pytelegrambot API
import telebot
from telebot import types

# %%
import requests
import json

class telegram_bot():
    def __init__(self):
        self.token = "1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ"    #write your token here!
        self.url = f"https://api.telegram.org/bot{self.token}"

    def get_updates(self,offset=None):
        url = self.url+"/getUpdates?timeout=100"
        if offset:
            url = url+f"&offset={offset+1}"
        url_info = requests.get(url)
        return json.loads(url_info.content)

    def send_message(self,msg,chat_id):
        url = self.url + f"/sendMessage?chat_id={chat_id}&text={msg}"
        if msg is not None:
            requests.get(url)

    def grab_token(self):
        return tokens

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC  #importing machine learning classification algorithm
import random
import pickle

# %%
# training data
data = [["Hi Good Morning",0],["Hello, How are you?",0],["heya",0],['hello',0],['hola',0],['How are you',0]
        ,["What are the Programs offered by NHCE?",1],["program",1],["What are the available programs in this college?",1]
        ,["Can you walk me through available programs?",1],['courses',1],['course',1],['show the courses available',1],["How can you help me",1]
        ,["I want to enroll",2],["enroll",2]
        ,["Tell me some jokes",3],["jokes joke",3],["I am bored",3],['joke',3]
        ,['thanks',4],['thank you',4],['i am so greatful to you',4],['have a nice day',4],['bye',4],['leave',4],['exit',4],['see you',4]
        ,["Tell me about this college",9],["tell me about NHCE",9],["Introduction of NHCE",9],["history of NHCE",9],["How is the Placement oppertunities in NHCE?",9]
        
        ]

# %%
#converting it into pandas dataframe
df = pd.DataFrame(data, columns = ['text', 'intent'])

# %%
df   #1 -> availability and 0 -> greeting
# Out:
#                                                 text  intent
# 0                                    Hi Good Morning       0
# 1                                Hello, How are you?       0
# 2                                               heya       0
# 3                                              hello       0
# 4                                               hola       0
# 5                                        How are you       0
# 6             What are the Programs offered by NHCE?       1
# 7                                            program       1
# 8   What are the available programs in this college?       1
# 9        Can you walk me through available programs?       1
# 10                                           courses       1
# 11                                            course       1
# 12                        show the courses available       1
# 13                               How can you help me       1
# ...

# %%
x = df['text']   #seperating x from data
y = df['intent']   # seperating y from data (intents are encoded into numbers as machine can only predict numbers)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(x)  # X has tfidfed vectors

# %%
clf  = LinearSVC(max_iter=10000, C=0.1) #initializing the classifier

# %%
clf.fit(X,y) #creating the model. after fitting model is ready
# Out:
# LinearSVC(C=0.1, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=10000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %% [markdown]
# <h3>Saving and loading the model</h3>

# %% [markdown]
# <h3>MINI Dataset</h3>

# %%
responses = { 0 : {"intent":"greetings",
                   "response":['Hi dear, How can i help you?','hello,How can i help you?','Watsupp dude,How can i help you?']}, 
             
              1 : {"intent":"availablePrograms",
                   "response":['Currently NHCE offer following Two Programs:','1> UG (Undergraduate Degree)',
                               '2> PG (Postgraduate Degree)',
                               'Select the Program you want to enroll into?'],
                   '1' :['Here are the list of courses for Undergraduate degree:','1> CSE (Computer Science Engineering)',
                         '2> ISE (Information Science Engineering)',
                         '3> ME (Mechanical Engineering)','4> CE (Civil Engineering)',
                         '5> ECE (Electronics and Communication Engineering)',
                         '6> EEE (Electrical and Electronics Engineering','Please, select the Course for more details'],
                   '2' :['Here are the list of courses for Undergraduate degree:','1> MBA (Master of Business Administration)',
                         '2> MIT (Master of Technology)','3> MCA (Master of Computer Application',
                         'Please, select the Course for more details'],
                   '1.1':['Computer Science Engineering is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 4years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/department-of-computer-science-engineering/syllabus/ ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course'],
                   '1.2':['Information Science Engineering is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 4years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/department-of-information-science-engineering/syllabus/ ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course'],
                   '1.3':['Mechanical Engineering is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 4years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/department-of-mechanical-engineering/syllabus/ ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course'],
                   '1.4':['Civil Engineering is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 4years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/department-of-civil-engineering/syllabus/ ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course'],
                   '1.5':['Electronics and Communication Engineering is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 4years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/department-of-electronics-and-communication-engineering/syllabus/ ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course'],
                   '1.6':['Electrical and Electronics Engineering is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 4years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/department-of-electrical-and-electronics-engineering/syllabus/ ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course'],
                   
                   '2.1':['Master of Business Administration is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 2years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/mba/programs/ ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course'],
                   '2.2':['Master of Technology is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 2years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/programs/#postgraduate-programs ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course'],
                   '2.3':['Master of Computer Application is one of the best program that NHCE offers with the support and high qualified teachers of this Dept NHCE is able to showcase 100% placement every year.',
                          'Total Duration for this Program : 2years.',
                          'Check out the syllabus here: http://newhorizonindia.edu/nhengineering/mca/programs/ ',
                          'type: "programs"  to select other Program',
                          'type: "enroll" and submit your Mobile No and Email address to get enroll in to this Course']
                   },
             
              2 : {"intent":"enroll", "response":['Thank You for showing interest in this course.','Your seat has been successfully reserved for this course',
                                                  'Our Addmision Department team will contact you shortly.'] },
             
              3 : {"intent":"jokes", "response":["Teacher: “John, why are you doing your math multiplication on the floor?”\nJohn: “You told me to do it without using tables.”\n HAHAH...",
                                            "James Bond approached by a student \nStudent: Hello sir \nBond: I'm Bond, James Bond\nStudent: OMG I knew it was you, I always wanted to be an agent like you, what should I do to be one.\nBOND: A lot depends on your academic performance, tell me what's your GPA?\nStudent: Four........... Two point four.\n hahaha.....",
                                            'Teacher: “Why are you late, Joseph?”\nJoseph: “Because of a sign down the road.”\nTeacher: “What does a sign have to do with you being late?”\nJoseph: “The sign said, ‘School Ahead, Go Slow!”\nHAAHAHAH....',
                                            'Teacher: “This essay on your dog is, word for word, the same as your brother’s.”\nStudent: Yes, sir, it is the same dog.”\nhahahahahHAHAH....',
                                            '“Isn’t the principal a dummy!” – said a boy to a girl.\n“Well, do you know who I am?” – asked the girl.\n“No.” – replied the boy.\n“I’m the principal’s daughter.” – said the girl.\n“And do you know who I am?” – asked the boy.\n“No.” – she replied.\n“Thank goodness!” – said the boy with a sign of relief.\n hahahahAHHAHAHHAH.........'
                                            ]},
              4: {"intent":"exit","response":['Have a good day, b-bye!','Bye!','See you soon!','Nice talking to you!','Thank you for choosing NHCE']},
              9 : {"intent":"information", 
                   "response": ['New Horizon College of Engineering is an Autonomous private Engineering college affiliated to VTU and ranked No. 3 in Bangalore and "A" grade by NAAC. It is located near Marathalli, outer Ring Road within the heart of big companies.',
                                'Chairman of NHCE is Dr. Mohan Maghnani.',
                                'NHCE always focuses on the quality education with the industry exposure and has a highest placement rate.',
                                'Please note that NHCE is an Autonomous Engineering College which has wide variety of BENEFITS.',
                                '> Academic Freedom','> Choice-Based Credit System (CBCS)','> Better Subject Choice and Electives',
                                '> Make-up & Fastrack Examination and many more...'
                                '\n\nDo you know what.... This is the most asked question by most of the visitors here. haha']}
              
              }

# %% [markdown]
# <h1>After training deploying model for chatbot</h1>

# %%
import time

tbot = telegram_bot()

update_id = None
predicted_flag=1
userResponse=""




def make_reply(user_response):
    global predicted_flag
    global userResponse
    lstReply = []

    
    

    """since mero above cell ma vako " responses " dictionary ma kunai kunai ma " intent " ta xa but " response " ko replace ma "1" ,"2","3",etc garera number
    haru xa so kaila kai chatbot le question soda , 'user_response' chai 1,2,3,etc.. huna ni sakxa so to provide the user with the correct result 
    following comparison is done 
    
    if 'user_response' number hunxa vane 'responses' dictionary ko either '1' or'2' or '3',etc key as a response reply garnu paryo
    else default 'response' vanne key nai as a response reply garne"""

    #checking for null response
    if(user_response is None):
      print("hello")

    elif(user_response.isnumeric()):

      
      previousUserResponse = userResponse

      #to show buttons instead of keyboard
      if(int(user_response)==1 and previousUserResponse.isalpha()):
        tb = telebot.TeleBot("1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ")
        if(tb.get_updates()):
          chat_id = tb.get_updates()[-1].message.chat.id
        
        markup = types.ReplyKeyboardMarkup(row_width=3)
        itembtn1 = types.KeyboardButton('1')
        itembtn2 = types.KeyboardButton('2')
        itembtn3 = types.KeyboardButton('3')
        itembtn4 = types.KeyboardButton('4')
        itembtn5 = types.KeyboardButton('5')
        itembtn6 = types.KeyboardButton('6')
        itembtn7 = types.KeyboardButton('Select Other Programs')
        markup.add(itembtn1, itembtn2,itembtn3, itembtn4,itembtn5, itembtn6,itembtn7)
        tb.send_message(chat_id, "Choose one letter:", reply_markup=markup)
          
          
      
      elif(int(user_response)==2 and previousUserResponse.isalpha()):
        tb = telebot.TeleBot("1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ")
        if(tb.get_updates()):
            chat_id = tb.get_updates()[-1].message.chat.id
        markup = types.ReplyKeyboardMarkup(row_width=3)
        itembtn1 = types.KeyboardButton('1')
        itembtn2 = types.KeyboardButton('2')
        itembtn3 = types.KeyboardButton('3')
        itembtn4 = types.KeyboardButton('Select Other Programs')
        markup.add(itembtn1, itembtn2,itembtn3,itembtn4)
        tb.send_message(chat_id, "Choose one letter:", reply_markup=markup)
          
      if(previousUserResponse.isnumeric()):
        userResponse = previousUserResponse+'.'+user_response
      else:
        temp = previousUserResponse.split('.')
        print(user_response)
        if(temp[0].isnumeric()):

          if(user_response in ['1','2','3','4','5','6'] and temp[0]=='1'):
            userResponse = temp[0]+'.'+user_response

            #showing button instead of keyboard
            tb = telebot.TeleBot("1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ")
            if(tb.get_updates()):
              chat_id = tb.get_updates()[-1].message.chat.id
            
            markup = types.ReplyKeyboardMarkup(row_width=3)
            itembtn1 = types.KeyboardButton('1')
            itembtn2 = types.KeyboardButton('2')
            itembtn3 = types.KeyboardButton('3')
            itembtn4 = types.KeyboardButton('4')
            itembtn5 = types.KeyboardButton('5')
            itembtn6 = types.KeyboardButton('6')
            itembtn7 = types.KeyboardButton('Select Other Programs')
            markup.add(itembtn1, itembtn2,itembtn3, itembtn4,itembtn5, itembtn6,itembtn7)
            tb.send_message(chat_id, "Choose one letter:", reply_markup=markup)

          elif(user_response in ['1','2','3'] and temp[0]=='2'):

            userResponse = temp[0]+'.'+user_response

            #showing button instead of keyboard
            tb = telebot.TeleBot("1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ")
            if(tb.get_updates()):
                chat_id = tb.get_updates()[-1].message.chat.id
            markup = types.ReplyKeyboardMarkup(row_width=3)
            itembtn1 = types.KeyboardButton('1')
            itembtn2 = types.KeyboardButton('2')
            itembtn3 = types.KeyboardButton('3')
            itembtn4 = types.KeyboardButton('Select Other Programs')
            markup.add(itembtn1, itembtn2,itembtn3,itembtn4)
            tb.send_message(chat_id, "Choose one letter:", reply_markup=markup)


          else:
            userResponse = "response"

        else:
          if(user_response in ['1','2']):

            userResponse = user_response
          else:
            userResponse = "response"
      if (responses[int(predicted_flag)]["intent"]!="greetings" and responses[int(predicted_flag)]["intent"]!="jokes" and responses[int(predicted_flag)]["intent"]!="exit"):
        lstReply = responses[int(predicted_flag)][userResponse]
        return lstReply
      else:
        lstReply.append(random.choice(responses[int(predicted_flag)][userResponse]))
        return lstReply

    #when the user_response is not numeric
    else:
      userResponse = "response"

      text_test = [user_response]
      X_test = vectorizer.transform(text_test)
      prediction = clf.predict(X_test)
      #creating copy of predicted intent
      predicted_flag = str(prediction[0])

      if (responses[prediction[0]]["intent"]!="greetings" and responses[prediction[0]]["intent"]!="jokes" and responses[prediction[0]]["intent"]!="exit"):
        lstReply = responses[prediction[0]][userResponse]
        
        if(responses[prediction[0]]["intent"]=="availablePrograms"):

          tb = telebot.TeleBot("1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ")
          if(tb.get_updates()):
            chat_id = tb.get_updates()[-1].message.chat.id
          markup = types.ReplyKeyboardMarkup(row_width=2)
          itembtn1 = types.KeyboardButton('1')
          itembtn2 = types.KeyboardButton('2')
          markup.add(itembtn1, itembtn2)
          tb.send_message(chat_id, "Choose one letter:", reply_markup=markup)

        #Sending photo if user wants to know about the infromation of NHCE
        elif(responses[prediction[0]]["intent"]=="information"):
          tb = telebot.TeleBot("1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ")
          # if(tb.get_updates()):
          #   chat_id = tb.get_updates()[-1].message.chat.id

          #   # All send_xyz functions which can take a file as an argument, can also take a file_id instead of a file.
          #   # sendPhoto
          #   photo = open('/content/drive/My Drive/Documents/Learning,Course,Internship work/Python/NLP ChatBot/Day 3 (Machine Learning Chatbot) Resources/nhcejpg.jpg', 'rb')
          #   tb.send_photo(chat_id, photo)
          #   time.sleep(2)
          # else:
          #   print("empty list please chat with chatbot")

        #sharing contact info
        elif(responses[prediction[0]]["intent"]=="enroll"):
          #showing button instead of keyboard
            tb = telebot.TeleBot("1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ")
            if(tb.get_updates()):
                chat_id = tb.get_updates()[-1].message.chat.id
            markup = types.ReplyKeyboardMarkup(row_width=1)
            itembtn5 = types.KeyboardButton('enroll',request_contact=True)
            markup.add(itembtn5)
            tb.send_message(chat_id, "Please Share your contact number:", reply_markup=markup)
            time.sleep(7)
        
      else:

        lstReply.append(random.choice(responses[prediction[0]][userResponse]))
      return lstReply

# %%
count=0
while True:
    global count
    print("...")
    
    updates = tbot.get_updates(offset=update_id)
    updates = updates['result']
    print(updates)
    if updates:
        for item in updates:
            update_id = item["update_id"]
            print(update_id)
            try:
                message = item["message"]["text"]
                print(message)
            except:
                message = None
            from_ = item["message"]["from"]["id"]
            print(from_)

            reply = make_reply(message)
            #checking for null response
            if(reply is None):
              print("hello")

            else:
              if(count==0):
                tbot.send_message("MAD: I was created by DIPESH SHRESTHA. I will answer everything about New Horizon College of Engineering."+"\n\n !!!type Jokes to hear some Academic funny jokes",from_)
                count+=1
                # tb = telebot.TeleBot("1180511938:AAEh7HXAt9PTufmy4wQgp2fi-mDwGd9o8XQ")
                # if(tb.get_updates()):
                #   chat_id = tb.get_updates()[-1].message.chat.id
                #   tbot.send_message(chat_id,"MAD: I was created by DIPESH SHRESTHA. I will answer everything about New Horizon College of Engineering."+"\n\n !!!type Jokes to hear some Academic funny jokes")
                #   count+=1

              for item in reply:
                tbot.send_message(item,from_)
# Out:
# ...
# [{'update_id': 49938797, 'message': {'message_id': 2143, 'from': {'id': 1072120206, 'is_bot': False, 'first_name': 'Dipesh', 'last_name': 'Shrestha', 'language_code': 'en'}, 'chat': {'id': 1072120206, 'first_name': 'Dipesh', 'last_name': 'Shrestha', 'type': 'private'}, 'date': 1592560502, 'text': 'how can u help me'}}]
# 49938797
# how can u help me
# 1072120206
# ...
# [{'update_id': 49938798, 'message': {'message_id': 2150, 'from': {'id': 1072120206, 'is_bot': False, 'first_name': 'Dipesh', 'last_name': 'Shrestha', 'language_code': 'en'}, 'chat': {'id': 1072120206, 'first_name': 'Dipesh', 'last_name': 'Shrestha', 'type': 'private'}, 'date': 1592560509, 'text': 'help'}}]
# 49938798
# help
# 1072120206
# ...
# ...

# %% [markdown]
# <h1>Stay MAD Stay Creative</h1>

# %% [markdown]
# <h1 style='color:blue'>We Are MAD & We All Deserve Better</h1>
